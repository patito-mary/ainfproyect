# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Cargar catalogo para acceder por columnas y por filas
cat = np.genfromtxt('MDPL2mini/sussing_125.z0.000.AHF_halos', names=True, comments='#', unpack=False, dtype=None)

# %%
df = pd.DataFrame(cat)

# %%
pd.options.display.max_columns = None
df.head()
# Out:
#            ID1    hostHalo2  numSubStruct3        M200c4  npart5  \
# 0  12642003069            0             72  1.141800e+14   86759
# 1  12642003149            0              8  6.173700e+12    5681
# 2  12642003146            0              2  4.708900e+12    4524
# 3  12642003071  12642003069              0  1.969100e+12    2265
# 4  12642003128  12642003069              0  1.493400e+12    1512
#
#              Xc6            Yc7            Zc8        VXc9       VYc10  \
# 0  521028.381348  932746.398926  426475.646973  -61.580002   53.330002
# 1  519935.241699  933129.760742  427102.142334  832.489990 -194.580002
# 2  519654.602051  932959.716797  427546.081543  731.640015  -19.330000
# 3  521068.115234  933620.178223  426098.815918 -147.580002  617.229980
# 4  521250.183105  933420.349121  426705.566406  342.579987 -754.659973
#
#         VZc11     R200c12      Rmax13          r214  mbp_offset15  \
# 0  201.899994  789.024780  355.728231  2.000000e+38  2.000000e+38
# ...

# %%
plot = sns.pairplot
